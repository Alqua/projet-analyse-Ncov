# %%
#import
import os
import numpy as np
import pandas as pd
import re
import jieba
import jieba.posseg as pseg

# %%
df_texts = pd.read_csv('../DATAFRAMES/df_texts_with_index.csv') #reading the dataframe with texts

# %%
df_texts.head()
# Out:
#    Unnamed: 0  id                                              texts
# 0           0   1  个临时发往武汉的口罩\n个临时发往武汉的口罩个临时发往武汉的口罩个临时发往武汉的口罩吴呈杰报...
# 1           1   2  武汉隔离疫区信息孤岛与一辆鄂车的漂流\n武汉隔离疫区信息孤岛与一辆鄂车的漂流武汉隔离疫区信息...
# 2           2   3  我家离华南海鲜市场很近返乡封城过年一位武汉大学生的过去一周\n我家离华南海鲜市场很近返乡封城...
# 3           3   4  疫情危机中不被看见的人们武汉周边城市百姓的自救行动\n疫情危机中不被看见的人们武汉周边城市百...
# 4           4   5  孝感前线医生武汉更难我们下面不好意思提要求\n孝感前线医生武汉更难我们下面不好意思提要求孝感...

# %% [markdown]
# Defining the function to keep only places mentioned in the texts

# %%
#function to keep words based on jieba tagging, here we only keep places (ns)

def keep_words(s, to_keep=['ns']):
    s_ = []
    pos_list = pseg.lcut(s)
    for item in pos_list:
        if item.flag in to_keep:
            s_.append(item.word)
    return s_

# %%
df_texts['places'] = df_texts.texts.apply(keep_words)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.640 seconds.
# Prefix dict has been built successfully.

# %%
df_texts.head()
# Out:
#    Unnamed: 0  id                                              texts  \
# 0           0   1  个临时发往武汉的口罩\n个临时发往武汉的口罩个临时发往武汉的口罩个临时发往武汉的口罩吴呈杰报...
# 1           1   2  武汉隔离疫区信息孤岛与一辆鄂车的漂流\n武汉隔离疫区信息孤岛与一辆鄂车的漂流武汉隔离疫区信息...
# 2           2   3  我家离华南海鲜市场很近返乡封城过年一位武汉大学生的过去一周\n我家离华南海鲜市场很近返乡封城...
# 3           3   4  疫情危机中不被看见的人们武汉周边城市百姓的自救行动\n疫情危机中不被看见的人们武汉周边城市百...
# 4           4   5  孝感前线医生武汉更难我们下面不好意思提要求\n孝感前线医生武汉更难我们下面不好意思提要求孝感...
#
#                                               places
# 0  [武汉, 武汉, 武汉, 武汉, 武汉, 广州, 中康, 中国, 美国, 河南, 中断, 江...
# 1  [武汉, 鄂车, 武汉, 鄂车, 武汉, 鄂车, 武汉, 鄂车, 武汉, 鄂州, 东西, 武...
# 2  [华南, 海鲜, 武汉, 华南, 海鲜, 武汉, 华南, 海鲜, 武汉, 华南, 海鲜, 武...
# 3  [武汉, 周边城市, 武汉, 周边城市, 武汉, 周边城市, 武汉, 周边城市, 武汉, 华...
# 4  [武汉, 武汉, 武汉, 武汉, 武安, 孝感市, 武汉, 武汉, 武汉, 武汉, 武安, ...

# %% [markdown]
# Now we have extracted all the places, we need to count them. To do that we need first make one list out of the list of list.

# %%
from  itertools import chain

# %%
fp = pd.Series(list(chain.from_iterable(df_texts['places'])))
fp.head(5)
# Out:
# 0    武汉
# 1    武汉
# 2    武汉
# 3    武汉
# 4    武汉
# dtype: object

# %%
cp = fp.value_counts()
cp.head(50)
# Out:
# 武汉     44339
# 中国     23038
# 湖北     10436
# 美国      9838
# 武汉市     7931
# 意大利     6849
# 北京      6619
# 城市      5219
# 上海      4912
# 湖北省     4072
# 韩国      3945
# 日本      3588
# 英国      3174
# 伊朗      3123
# 东西      2764
# 欧洲      2595
# 德国      2269
# 香港      2039
# 海鲜      1942
# 华南      1906
# 回国      1853
# 广州      1670
# 深度      1491
# 钟南山     1488
# 黄冈      1353
# 广东      1330
# 纽约      1289
# 法国      1288
# 西班牙     1287
# 深圳      1244
# 汉口      1103
# 浙江      1100
# 神山      1028
# 中东       961
# 武昌       903
# 东京       899
# 新加坡      860
# 温州       853
# 中南       831
# 泉州       816
# 上海市      806
# 印度       774
# 杭州       760
# 大邱       759
# 米兰       751
# 京        742
# 河南       739
# 黄冈市      706
# 山东       697
# 伦敦       685
# dtype: int64

# %% [markdown]
# Wuhan is definitely on top of that list and by a lot of counts. However, there are also a lot of trash: 东西 is not a place f.e. If we want to use this places to put them on a map we need to clean them a little or edit them manually. We are first going to try to do some cleaning, removing 东西, removing 市 from 武汉市, 省 from 湖北省 etc.

# %%
df_texts['texts'] = pd.Series(df_texts.texts).str.replace('市', '', regex=True)
#I am not sure how to write the character to replace at once, so we can just do one after the other. It works for sure
df_texts['texts'] = pd.Series(df_texts.texts).str.replace('东西', '', regex=True)
df_texts['texts'] = pd.Series(df_texts.texts).str.replace('省', '', regex=True)
df_texts['texts'] = pd.Series(df_texts.texts).str.replace('回国', '', regex=True)
df_texts['texts'] = pd.Series(df_texts.texts).str.replace('深度', '', regex=True)
df_texts['texts'] = pd.Series(df_texts.texts).str.replace('神山', '', regex=True)
df_texts['texts'] = pd.Series(df_texts.texts).str.replace('哥哥', '', regex=True)
df_texts['texts'] = pd.Series(df_texts.texts).str.replace('太阳', '', regex=True)
df_texts['texts'] = pd.Series(df_texts.texts).str.replace('上岗 ', '', regex=True)

# %%
df_texts['places'] = df_texts.texts.apply(keep_words)
fp = pd.Series(list(chain.from_iterable(df_texts['places'])))
cp = fp.value_counts()
cp.head(100)
# Out:
# 武汉      52335
# 中国      23035
# 湖北      14979
# 美国       9936
# 北京       7374
# 意大利      6849
# 上海       5813
# 韩国       3945
# 日本       3601
# 英国       3174
# 伊朗       3123
# 欧洲       2595
# 德国       2269
# 黄冈       2058
# 香港       2054
# 海鲜       1942
# 华南       1906
# 广州       1862
# 广东       1698
# 纽约       1512
# 钟南山      1488
# 浙江       1469
# 深圳       1454
# 西班牙      1287
# 法国       1287
# 汉口       1103
# 天津        973
# 温州        973
# 泉州        964
# 中东        961
#         ...
# 潜江        458
# 埃         443
# 东湖        440
# 福建        437
# 长江        426
# 天门        425
# 贵州        406
# 亚洲        405
# 纽约州       389
# 京东        388
# 巴西        376
# 加州        374
# 郑州        372
# 加拿大       368
# 宜昌        360
# 十堰        350
# 河北        346
# 越南        340
# 三联        339
# 上岗        337
# 亚太地区      336
# 咸宁        335
# 北非        332
# 瑞士        324
# 德塞        323
# 甘肃        322
# 新鲜        320
# 苏州        319
# 关联        318
# 黑龙江       318
# Length: 100, dtype: int64

# %% [markdown]
# There are still some mistakes such as 海鲜, 三联, 上岗, but we can delete them directly. The biggest problem was removing 市 from 武汉市, etc because in those cases, the occurences total was separated in two.

# %%
dcp = cp.to_frame().reset_index()

# %%
dcp.rename(columns = {'index':'places', 0: 'freq'}, inplace = True)

# %%
dcp.head(30)
# Out:
#    places   freq
# 0      武汉  52335
# 1      中国  23035
# 2      湖北  14979
# 3      美国   9936
# 4      北京   7374
# 5     意大利   6849
# 6      上海   5813
# 7      韩国   3945
# 8      日本   3601
# 9      英国   3174
# 10     伊朗   3123
# 11     欧洲   2595
# 12     德国   2269
# 13     黄冈   2058
# 14     香港   2054
# 15     海鲜   1942
# 16     华南   1906
# 17     广州   1862
# 18     广东   1698
# 19     纽约   1512
# 20    钟南山   1488
# 21     浙江   1469
# 22     深圳   1454
# 23    西班牙   1287
# 24     法国   1287
# 25     汉口   1103
# 26     天津    973
# 27     温州    973
# 28     泉州    964
# 29     中东    961

# %% [markdown]
# We are going to keep the first 100 values. Let's select the first 200 values clean it and take the first 100 based on that

# %%
dcpf = dcp.head(200)
dcpf
# Out:
#     places   freq
# 0       武汉  52335
# 1       中国  23035
# 2       湖北  14979
# 3       美国   9936
# 4       北京   7374
# 5      意大利   6849
# 6       上海   5813
# 7       韩国   3945
# 8       日本   3601
# 9       英国   3174
# 10      伊朗   3123
# 11      欧洲   2595
# 12      德国   2269
# 13      黄冈   2058
# 14      香港   2054
# 15      海鲜   1942
# 16      华南   1906
# 17      广州   1862
# 18      广东   1698
# 19      纽约   1512
# 20     钟南山   1488
# 21      浙江   1469
# 22      深圳   1454
# 23     西班牙   1287
# 24      法国   1287
# 25      汉口   1103
# 26      天津    973
# 27      温州    973
# 28      泉州    964
# 29      中东    961
# ..     ...    ...
# 170     东莞    165
# 171     上街    161
# 172      华    160
# 173     归国    158
# 174     宁波    156
# 175     上路    154
# 176     广水    153
# 177     美丽    152
# 178     大国    152
# 179     辽宁    151
# 180     大桥    150
# 181     印尼    150
# 182     普及    149
# 183     九江    149
# 184    洪山区    147
# 185     新城    145
# 186     回京    143
# 187    东南亚    141
# 188     江夏    140
# 189     吉林    140
# 190     无锡    135
# 191    哈尔滨    135
# 192     瑞典    135
# 193     孟北    133
# 194      中    133
# 195     迪拜    132
# 196     三亚    132
# 197     福利    132
# 198     城镇    131
# 199     中建    130
#
# [200 rows x 2 columns]

# %% [markdown]
# Deleting the problematic values. I did not keep places abbreviation like '京' or '美' as their meaning can vary depending on the context.

# %%
mask = dcpf['places'].isin(['海鲜', '三联', '上岗', '钟南山','京', '美', '英雄','西韦','上门','云','海关','商城','南','埃','京东','德塞','新鲜','关联','立马','德','中断','鄂','吉利','离汉','后湖','北'])
df_test = dcpf[mask]# testing the mask
print('values to delete frome places')
df_test
# Out:
# values to delete frome places
#     places  freq
# 15      海鲜  1942
# 20     钟南山  1488
# 41       京   743
# 45       美   653
# 47      英雄   620
# 50      西韦   598
# 51      上门   591
# 57       云   544
# 60      海关   536
# 62      商城   490
# 69       南   463
# 71       埃   443
# 79      京东   388
# 88      三联   339
# 89      上岗   337
# 94      德塞   323
# 96      新鲜   320
# 98      关联   318
# 101     立马   302
# 102      德   298
# 103     中断   296
# 111      鄂   276
# 118     吉利   257
# 122     离汉   248
# 124     后湖   244
# 125      北   242

# %% [markdown]
# to clean properly our dataframe, this time we need to see it in full.

# %%
pd.get_option("display.max_row")
# Out:
# 60

# %%
pd.set_option("display.max_rows", 200)

# %%
cleaned_dcpf = dcpf[~mask]
cleaned_dcpf
# Out:
#     places   freq
# 0       武汉  52335
# 1       中国  23035
# 2       湖北  14979
# 3       美国   9936
# 4       北京   7374
# 5      意大利   6849
# 6       上海   5813
# 7       韩国   3945
# 8       日本   3601
# 9       英国   3174
# 10      伊朗   3123
# 11      欧洲   2595
# 12      德国   2269
# 13      黄冈   2058
# 14      香港   2054
# 16      华南   1906
# 17      广州   1862
# 18      广东   1698
# 19      纽约   1512
# 21      浙江   1469
# 22      深圳   1454
# 23     西班牙   1287
# 24      法国   1287
# 25      汉口   1103
# 26      天津    973
# 27      温州    973
# 28      泉州    964
# 29      中东    961
# 30      河南    949
# 31      杭州    917
# 32      山东    912
# 33      武昌    902
# 34      江苏    899
# 35      东京    899
# 36     新加坡    860
# 37      中南    831
# 38      印度    774
# 39      大邱    759
# 40      米兰    751
# 42      四川    704
# 43      成都    699
# 44      伦敦    684
# 46      鄂州    638
# 48      荆州    602
# 49      湖南    601
# 52      重庆    584
# 53      南京    565
# 54      云南    563
# 55    澳大利亚    556
# 56     俄罗斯    552
# 58      襄阳    541
# 59      安徽    541
# 61      西安    506
# 63      泰国    490
# 64      江西    484
# 65      非洲    479
# 66      海南    479
# 67      北美    472
# 68      随州    468
# 70      潜江    458
# 72      东湖    440
# 73      福建    437
# 74      长江    426
# 75      天门    425
# 76      贵州    406
# 77      亚洲    405
# 78     纽约州    389
# 80      巴西    376
# 81      加州    374
# 82      郑州    372
# 83     加拿大    368
# 84      宜昌    360
# 85      十堰    350
# 86      河北    346
# 87      越南    340
# 90    亚太地区    336
# 91      咸宁    335
# 92      北非    332
# 93      瑞士    324
# 95      甘肃    322
# 97      苏州    319
# 99     黑龙江    318
# 100     长沙    305
# 104     荷兰    289
# 105    德黑兰    283
# 106     荆门    282
# 107     青岛    282
# 108     汉阳    281
# 109     巴黎    278
# 110     陕西    278
# 112    洛杉矶    274
# 113     广西    273
# 114     大城    271
# 115     汶川    268
# 116     罗马    263
# 117     埃及    258
# 119    江汉区    252
# 120    以色列    249
# 121   华盛顿州    248
# 123    江夏区    247
# 126     山西    242
# 127     东北    241
# 128    正和岛    241
# 129     江汉    238
# 130     济南    237
# 131     大街    233
# 132    土耳其    229
# 133     西湖    228
# 134     台湾    227
# 135     新疆    227
# 136     长大    226
# 137      东    226
# 138     外国    225
# 139    华盛顿    223
# 140     澳洲    218
# 141     礼拜    216
# 142     入口    211
# 143    菲律宾    209
# 144    武昌区    208
# 145     大都    207
# 146     欧美    206
# 147     波及    206
# 148     昆明    205
# 149     横滨    199
# 150     厦门    195
# 151    内蒙古    189
# 152     挪威    189
# 153     北欧    188
# 154     海滩    186
# 155     珠海    182
# 156   马来西亚    181
# 157    旧金山    181
# 158    江岸区    176
# 159     佛山    176
# 160     沈阳    175
# 161     新建    173
# 162    青山区    172
# 163     伦理    172
# 164     新春    171
# 165     澳门    170
# 166     中山    170
# 167     安庆    169
# 168    奥地利    167
# 169     北道    166
# 170     东莞    165
# 171     上街    161
# 172      华    160
# 173     归国    158
# 174     宁波    156
# 175     上路    154
# 176     广水    153
# 177     美丽    152
# 178     大国    152
# 179     辽宁    151
# 180     大桥    150
# 181     印尼    150
# 182     普及    149
# 183     九江    149
# 184    洪山区    147
# 185     新城    145
# 186     回京    143
# 187    东南亚    141
# 188     江夏    140
# 189     吉林    140
# 190     无锡    135
# 191    哈尔滨    135
# 192     瑞典    135
# 193     孟北    133
# 194      中    133
# 195     迪拜    132
# 196     三亚    132
# 197     福利    132
# 198     城镇    131
# 199     中建    130

# %% [markdown]
# We can check the places' name. If I have a doubt about a place, I will search it with google map, if that brings no result, I delete it by adding it to the mask and so on. I had to clean until 123 to keep the first 100.

# %%
selected = cleaned_dcpf.head(100)
selected
# Out:
#     places   freq
# 0       武汉  52335
# 1       中国  23035
# 2       湖北  14979
# 3       美国   9936
# 4       北京   7374
# 5      意大利   6849
# 6       上海   5813
# 7       韩国   3945
# 8       日本   3601
# 9       英国   3174
# 10      伊朗   3123
# 11      欧洲   2595
# 12      德国   2269
# 13      黄冈   2058
# 14      香港   2054
# 16      华南   1906
# 17      广州   1862
# 18      广东   1698
# 19      纽约   1512
# 21      浙江   1469
# 22      深圳   1454
# 23     西班牙   1287
# 24      法国   1287
# 25      汉口   1103
# 26      天津    973
# 27      温州    973
# 28      泉州    964
# 29      中东    961
# 30      河南    949
# 31      杭州    917
# 32      山东    912
# 33      武昌    902
# 34      江苏    899
# 35      东京    899
# 36     新加坡    860
# 37      中南    831
# 38      印度    774
# 39      大邱    759
# 40      米兰    751
# 42      四川    704
# 43      成都    699
# 44      伦敦    684
# 46      鄂州    638
# 48      荆州    602
# 49      湖南    601
# 52      重庆    584
# 53      南京    565
# 54      云南    563
# 55    澳大利亚    556
# 56     俄罗斯    552
# 58      襄阳    541
# 59      安徽    541
# 61      西安    506
# 63      泰国    490
# 64      江西    484
# 65      非洲    479
# 66      海南    479
# 67      北美    472
# 68      随州    468
# 70      潜江    458
# 72      东湖    440
# 73      福建    437
# 74      长江    426
# 75      天门    425
# 76      贵州    406
# 77      亚洲    405
# 78     纽约州    389
# 80      巴西    376
# 81      加州    374
# 82      郑州    372
# 83     加拿大    368
# 84      宜昌    360
# 85      十堰    350
# 86      河北    346
# 87      越南    340
# 90    亚太地区    336
# 91      咸宁    335
# 92      北非    332
# 93      瑞士    324
# 95      甘肃    322
# 97      苏州    319
# 99     黑龙江    318
# 100     长沙    305
# 104     荷兰    289
# 105    德黑兰    283
# 106     荆门    282
# 107     青岛    282
# 108     汉阳    281
# 109     巴黎    278
# 110     陕西    278
# 112    洛杉矶    274
# 113     广西    273
# 114     大城    271
# 115     汶川    268
# 116     罗马    263
# 117     埃及    258
# 119    江汉区    252
# 120    以色列    249
# 121   华盛顿州    248
# 123    江夏区    247

# %% [markdown]
# If we look at the end of the dataframe, we do not see any problematic values. We can go further and eventually we will still have to correct a few thing while displaying it on the map.

# %%
selected = selected.sort_values(by = 'freq', ascending = False ).reset_index(drop=True)
selected
# Out:
#    places   freq
# 0      武汉  52335
# 1      中国  23035
# 2      湖北  14979
# 3      美国   9936
# 4      北京   7374
# 5     意大利   6849
# 6      上海   5813
# 7      韩国   3945
# 8      日本   3601
# 9      英国   3174
# 10     伊朗   3123
# 11     欧洲   2595
# 12     德国   2269
# 13     黄冈   2058
# 14     香港   2054
# 15     华南   1906
# 16     广州   1862
# 17     广东   1698
# 18     纽约   1512
# 19     浙江   1469
# 20     深圳   1454
# 21    西班牙   1287
# 22     法国   1287
# 23     汉口   1103
# 24     温州    973
# 25     天津    973
# 26     泉州    964
# 27     中东    961
# 28     河南    949
# 29     杭州    917
# 30     山东    912
# 31     武昌    902
# 32     江苏    899
# 33     东京    899
# 34    新加坡    860
# 35     中南    831
# 36     印度    774
# 37     大邱    759
# 38     米兰    751
# 39     四川    704
# 40     成都    699
# 41     伦敦    684
# 42     鄂州    638
# 43     荆州    602
# 44     湖南    601
# 45     重庆    584
# 46     南京    565
# 47     云南    563
# 48   澳大利亚    556
# 49    俄罗斯    552
# 50     安徽    541
# 51     襄阳    541
# 52     西安    506
# 53     泰国    490
# 54     江西    484
# 55     非洲    479
# 56     海南    479
# 57     北美    472
# 58     随州    468
# 59     潜江    458
# 60     东湖    440
# 61     福建    437
# 62     长江    426
# 63     天门    425
# 64     贵州    406
# 65     亚洲    405
# 66    纽约州    389
# 67     巴西    376
# 68     加州    374
# 69     郑州    372
# 70    加拿大    368
# 71     宜昌    360
# 72     十堰    350
# 73     河北    346
# 74     越南    340
# 75   亚太地区    336
# 76     咸宁    335
# 77     北非    332
# 78     瑞士    324
# 79     甘肃    322
# 80     苏州    319
# 81    黑龙江    318
# 82     长沙    305
# 83     荷兰    289
# 84    德黑兰    283
# 85     荆门    282
# 86     青岛    282
# 87     汉阳    281
# 88     陕西    278
# 89     巴黎    278
# 90    洛杉矶    274
# 91     广西    273
# 92     大城    271
# 93     汶川    268
# 94     罗马    263
# 95     埃及    258
# 96    江汉区    252
# 97    以色列    249
# 98   华盛顿州    248
# 99    江夏区    247

# %%
from geopy.geocoders import Nominatim
import time

# %%
geolocator = Nominatim(user_agent="Your_Name")

def ex_lat(address):
    time.sleep(1) #adding 1 second delay before each request to avoid making too many request to nominatim servers
    location = geolocator.geocode(address)
    return location.latitude
    
def ex_long(address):
    time.sleep(1)
    location = geolocator.geocode(address)
    return location.longitude

# %%
selected['lat'] = selected['places'].apply(ex_lat)
# 73     河北    346  39.000000  116.000000
# 74     越南    340  13.290403  108.426511
# 75   亚太地区    336  31.932000  120.915383
# 76     咸宁    335  29.843754  114.316942
# 77     北非    332  47.858433   -3.605622
# 78     瑞士    324  46.798562    8.231974
# 79     甘肃    322  38.000000  102.000000
# 80     苏州    319  31.301693  120.581073
# 81    黑龙江    318  48.000005  127.999992
# 82     长沙    305  28.230206  112.933586
# 83     荷兰    289  52.500170    5.748082
# 84    德黑兰    283  35.689252   51.389600
# 85     荆门    282  31.037525  112.193798
# 86     青岛    282  36.063803  120.378137
# 87     汉阳    281  28.556200  112.349761
# 88     陕西    278  35.889410  109.135728
# 89     巴黎    278  48.856697    2.351462
# 90    洛杉矶    274  34.053691 -118.242766
# 91     广西    273  24.000000  109.000000
# 92     大城    271  14.353543  100.564568
# 93     汶川    268  31.201709  103.335476
# 94     罗马    263  23.297100  109.484000
# 95     埃及    258  26.254049   29.267547
# 96    江汉区    252  30.605440  114.251296
# 97    以色列    249  31.531311   34.866765
# 98   华盛顿州    248  47.286835 -120.212613
# 99    江夏区    247  30.378049  114.316169

# %%
# import folium
import folium

# %%
# Make an empty map
m = folium.Map(location=[32.0609736, 118.7916458], tiles="OpenStreetMap", zoom_start=4)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ce7c4336539c4feb80b96f11843a6ae1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ce7c4336539c4feb80b96f11843a6ae1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ce7c4336539c4feb80b96f11843a6ae1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ce7c4336539c4feb80b96f11843a6ae1%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B32.0609736%2C%20118.7916458%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
for places, freq, lat, long in zip(
    selected.places, 
    selected.freq, 
    selected.lat,
    selected.long):
    
    label= '{}, {}'.format(places, freq) # Define label here to reuse after
    
    m.add_child(
        folium.Circle(
            [lat,long],
            label = label,
            popup = label,
            radius = float(freq)*7, # define how big is the circle
            color = 'crimson',
            fill = True,
            fill_color = 'crimson',
            fill_opacity = 0.3
        ).add_to(m)
    )

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ce7c4336539c4feb80b96f11843a6ae1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ce7c4336539c4feb80b96f11843a6ae1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ce7c4336539c4feb80b96f11843a6ae1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ce7c4336539c4feb80b96f11843a6ae1%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B32.0609736%2C%20118.7916458%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
#save the map to inspect it
m.save("maps/places_1st100freq.html")

# %% [markdown]
# With this map, we could see that there was still a few problem with our data. 中南 South central Chine and 中东 Middle east are wrongly located, same for 加州 JiaZhou California showing in Japan. Also concerned are Yataidiqu: Asia-pacific area, Huanan, Dacheng, Beifei.

# %%
print(geolocator.geocode('中东'))
print(geolocator.geocode('الشرق الاوسط'))
#only giving a hint with viewbox actually help a little to locate middle east properly,
#we will have to enter the coordinates manually

geolocator.geocode('Middle East', viewbox = ((28,30),(41,43)) )

# %%
print(geolocator.geocode('中南'))
print(geolocator.geocode('中南地区'))

# %% [markdown]
# No success here as well. Let's just enter manually the coordinate of Changsha, which is more or less in the center of the area voir wiki: https://fr.wikipedia.org/wiki/Zhongnan coordinates: 29.00244602807003, 112.96734232025437
#
# However, Changsha is also in the dataframe and if two coordinates are the same, the map only keep the last one. We need to pay attention to that and enter coordinates nearby but not the same.
# We can print only the location we want to edit first to know their index number.

# %%
mask = selected['places'].isin(['华南','中东','中南', '北非', '亚太地区' ,'加州', '大城'])
df_look = selected[mask]# check
df_look
# Out:
#    places  freq        lat        long
# 15     华南  1906  46.235427  130.557065
# 27     中东   961  23.726500  108.735000
# 35     中南   831  36.659300  126.672900
# 68     加州   374  35.726318  138.793924
# 75   亚太地区   336  31.932000  120.915383
# 77     北非   332  47.858433   -3.605622
# 92     大城   271  14.353543  100.564568

# %% [markdown]
# Let's edit manually our dataframe.

# %%
selected.at[15, 'lat'] = '24.990994022242646' #edit 华南
selected.at[15, 'long'] = '112.86380926909548' #edit 华南

selected.at[27, 'lat'] = '30.980457' #edit 中东
selected.at[27, 'long'] = '40.857491' #edit 中东

selected.at[35, 'lat'] = '27.865395854384015' #edit 中南
selected.at[35, 'long'] = '112.37254013136757' #edit 中南

selected.at[68, 'lat'] = '36.48091646860382' #edit 加州, California
selected.at[68, 'long'] = '-119.51141777744824' #edit 加州, California

selected.at[75, 'lat'] =  '10.381340' #edit 亚太地区, Asia-Pacific
selected.at[75, 'long'] = '112.615423' #edit 亚太地区, Asia-Pacific

selected.at[77, 'lat'] = '19.54918' #edit 北非
selected.at[77, 'long'] = '-7.7429868' #edit 北非

selected.at[92, 'lat'] = '38.70030284043825'  #edit 大城
selected.at[92, 'long'] = '116.64556403067809' #edit 大城

selected
# Out:
#    places   freq        lat        long   freq2
# 0      武汉  52335  30.595105  114.299935  52,335
# 1      中国  23035  35.000074  104.999927  23,035
# 2      湖北  14979  31.151725  112.878322  14,979
# 3      美国   9936  39.783730 -100.445882   9,936
# 4      北京   7374  39.906217  116.391276   7,374
# 5     意大利   6849  42.638426   12.674297   6,849
# 6      上海   5813  31.232276  121.469207   5,813
# 7      韩国   3945  36.638392  127.696119   3,945
# 8      日本   3601  36.574844  139.239418   3,601
# 9      英国   3174  54.702354   -3.276575   3,174
# 10     伊朗   3123  32.647531   54.564352   3,123
# 11     欧洲   2595  51.000000   10.000000   2,595
# 12     德国   2269  51.083420   10.423447   2,269
# 13     黄冈   2058  30.456019  114.867323   2,058
# 14     香港   2054  22.279328  114.162813   2,054
# 15     华南   1906  24.990994  112.863809   1,906
# 16     广州   1862  23.130196  113.259294   1,862
# 17     广东   1698  23.135769  113.198269   1,698
# 18     纽约   1512  40.712728  -74.006015   1,512
# 19     浙江   1469  29.000000  120.000000   1,469
# 20     深圳   1454  22.555454  114.054330   1,454
# 21    西班牙   1287  39.326068   -4.837979   1,287
# 22     法国   1287  46.603354    1.888334   1,287
# 23     汉口   1103  30.621651  114.249414   1,103
# 24     温州    973  27.996390  120.695345     973
# 25     天津    973  39.085673  117.195107     973
# 26     泉州    964  24.875549  118.672360     964
# 27     中东    961  30.980457   40.857491     961
# 28     河南    949  34.000000  114.000000     949
# 29     杭州    917  30.248963  120.205234     917
# 30     山东    912  36.000000  119.000000     912
# 31     武昌    902  30.556700  114.310985     902
# 32     江苏    899  33.000000  120.000000     899
# 33     东京    899  35.681091  139.767186     899
# 62     长江    426  30.564146  114.291705     426
# 63     天门    425  30.663552  113.161619     425
# 64     贵州    406  27.000000  107.000000     406
# 65     亚洲    405  51.208697   89.234375     405
# 66    纽约州    389  43.156168  -75.844995     389
# 67     巴西    376 -10.333333  -53.200000     376
# 68     加州    374  36.480916 -119.511418     374
# 69     郑州    372  34.748724  113.619148     372
# 70    加拿大    368  61.066692 -107.991707     368
# 71     宜昌    360  30.694088  111.280307     360
# 72     十堰    350  32.631488  110.792752     350
# 73     河北    346  39.000000  116.000000     346
# 74     越南    340  13.290403  108.426511     340
# 75   亚太地区    336  10.381340  112.615423     336
# 76     咸宁    335  29.843754  114.316942     335
# 77     北非    332  19.549180   -7.742987     332
# 78     瑞士    324  46.798562    8.231974     324
# 79     甘肃    322  38.000000  102.000000     322
# 80     苏州    319  31.301693  120.581073     319
# 81    黑龙江    318  48.000005  127.999992     318
# 82     长沙    305  28.230206  112.933586     305
# 83     荷兰    289  52.500170    5.748082     289
# 84    德黑兰    283  35.689252   51.389600     283
# 85     荆门    282  31.037525  112.193798     282
# 86     青岛    282  36.063803  120.378137     282
# 87     汉阳    281  28.556200  112.349761     281
# 88     陕西    278  35.889410  109.135728     278
# 89     巴黎    278  48.856697    2.351462     278
# 90    洛杉矶    274  34.053691 -118.242766     274
# 91     广西    273  24.000000  109.000000     273
# 92     大城    271  38.700303  116.645564     271
# 93     汶川    268  31.201709  103.335476     268
# 94     罗马    263  23.297100  109.484000     263
# 95     埃及    258  26.254049   29.267547     258
# 96    江汉区    252  30.605440  114.251296     252
# 97    以色列    249  31.531311   34.866765     249
# 98   华盛顿州    248  47.286835 -120.212613     248
# 99    江夏区    247  30.378049  114.316169     247

# %%
#reset the map
m = folium.Map(location=[32.0609736, 118.7916458], tiles="OpenStreetMap", zoom_start=4)

#add a title
title = "First 100 places' occurence in nCovMemory corpus"
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(title)   


m.get_root().html.add_child(folium.Element(title_html))

#write again the circles with the changes made
for places, freq, lat, long, freq2 in zip(
    selected.places, 
    selected.freq, 
    selected.lat,
    selected.long,
    selected.freq2):
    
    label= '{}: {}'.format(places, freq2) # Define label here to reuse after
    
    m.add_child(
        folium.Circle(
            [lat,long],
            label = label,
            popup = label,
            radius = float(freq)*7, # define how big is the circle
            color = 'crimson',
            fill = True,
            fill_color = 'crimson',
            fill_opacity = 0.3
        ).add_to(m)
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2264f49ee85e> in <module>
#       1 #reset the map
# ----> 2 m = folium.Map(location=[32.0609736, 118.7916458], tiles="OpenStreetMap", zoom_start=4)
#       3
#       4 #add a title
#       5 title = "First 100 places' occurence in nCovMemory corpus"
#
# NameError: name 'folium' is not defined

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8b172177401049f0ae9b7df90bdadea5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%3Ch3%20align%3D%22center%22%20style%3D%22font-size%3A16px%22%3E%3Cb%3EFirst%20100%20places%27%20occurence%20in%20nCovMemory%20corpus%3C/b%3E%3C/h3%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8b172177401049f0ae9b7df90bdadea5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8b172177401049f0ae9b7df90bdadea5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8b1721 ...

# %%
#save the map
m.save("maps/places_1st100freq.html")

# %% [markdown]
# et voilà!!
